# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

for x in range(5):
    ax.plot(x, x*x, 'o')

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')

# Set title
ax.set_title('Quadratic Plot')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

x_values = range(5)
y_values = [x**2 for x in x_values]

ax.plot(x_values, y_values, '-o')

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')

# Set title
ax.set_title('Quadratic Plot')

# Display the plot
plt.show()

# %%
import numpy as np

data = [[ 0.00000000e+00,  2.57782052e-01,  0.00000000e+00,  2.40000000e-02,  0.00000000e+00,  1.06500000e-01,  0.00000000e+00],
        [ 3.06890567e-01,  6.81433946e-17,  3.99283838e-01,  0.00000000e+00,  1.06500000e-01,  9.76996262e-18,  0.00000000e+00],
        [ 0.00000000e+00, -3.06890567e-01, -0.00000000e+00,  4.72000000e-01,  0.00000000e+00,  8.80000000e-02,  0.00000000e+00],
        [ 0.00000000e+00,  0.00000000e+00, -7.07106781e-01,  0.00000000e+00,  1.00000000e+00,  0.00000000e+00, -3.00028968e-12],
        [ 0.00000000e+00,  1.00000000e+00,  0.00000000e+00, -1.00000000e+00,  0.00000000e+00, -1.00000000e+00,  0.00000000e+00],
        [ 1.00000000e+00,  2.22044605e-16,  7.07106781e-01,  0.00000000e+00,  1.89648297e-12,  1.11022302e-16, -1.00000000e+00]]

robosuite_jacobian = np.array(data)
# print(numpy_array)

# %%
import numpy as np

mass_matrix = [[ 6.71292152e+00,  3.13731600e-16,  8.77128417e-01,  1.74269984e-25,  2.86183501e-02,  2.79894985e-17, -1.00000015e-01],
               [ 3.13731600e-16,  4.76673450e+00,  1.94761633e-16, -1.07951646e+00,  6.35455023e-18, -2.27008260e-01, -2.22044637e-17],
               [ 8.77128417e-01,  1.94761633e-16,  3.17755931e+00,  1.23227488e-25, -2.44859012e-01,  2.42377922e-17, -7.07106888e-02],
               [ 1.74269984e-25, -1.07951646e+00,  1.23227488e-25,  2.51031683e+00,  3.30484644e-37,  2.82674898e-01, -1.74269984e-25],
               [ 2.86183501e-02,  6.35455023e-18, -2.44859012e-01,  3.30484644e-37,  1.40887154e+00,  9.11074633e-19, -4.89733038e-13],
               [ 2.79894985e-17, -2.27008260e-01,  2.42377922e-17,  2.82674898e-01,  9.11074633e-19,  1.05534901e+00, -1.11022321e-17],
               [-1.00000015e-01, -2.22044637e-17, -7.07106888e-02, -1.74269984e-25, -4.89733038e-13, -1.11022321e-17,  8.14285729e-01]]

numpy_mass_matrix = np.array(mass_matrix)
# print(numpy_mass_matrix)

#This is new

# %%
new_robo = np.array([[ 5.55679507e+00,  3.85546947e-15,  4.04798713e-01, -3.73386051e-15,  3.44007085e-02, -3.72049080e-15, -5.48150151e-02],
                        [ 3.85546947e-15,  4.07408951e+00,  8.79994389e-04, -6.39489108e-01, -1.24450000e-03, -9.75040168e-02, -1.21713782e-17],
                        [ 4.04798713e-01,  8.79994389e-04,  2.53324418e+00, -8.79994389e-04, -4.95448767e-03, -8.79994389e-04, -3.87600689e-02],
                        [-3.73386051e-15, -6.39489108e-01, -8.79994389e-04,  2.08011580e+00,  1.24450000e-03,  1.63551960e-01, -1.74270418e-25],
                        [ 3.44007085e-02, -1.24450000e-03, -4.95448767e-03,  1.24450000e-03,  1.08224138e+00,  1.24450000e-03, -2.68252341e-13],
                        [-3.72049080e-15, -9.75040168e-02, -8.79994389e-04,  1.63551960e-01,  1.24450000e-03,  9.25984327e-01, -6.08568936e-18],
                        [-5.48150151e-02, -1.21713782e-17, -3.87600689e-02, -1.74270418e-25, -2.68252341e-13, -6.08568936e-18,  7.69100729e-01]])

# %%
#OLD
import numpy as np

data = [[ 6.77969537e+00,  3.28558388e-16,  9.57081723e-01, -1.47801557e-23,  6.15817352e-02,  3.01152918e-17, -1.00000530e-01],
        [ 3.28558388e-16,  4.86560848e+00,  3.48359232e-12, -1.17180563e+00, -4.92622929e-12, -2.23300746e-01, -2.22045782e-17],
        [ 9.57081723e-01,  3.48359232e-12,  3.27329375e+00, -3.48337981e-12, -2.05389745e-01, -3.48335303e-12, -7.07110529e-02],
        [-1.47801557e-23, -1.17180563e+00, -3.48337981e-12,  2.67164295e+00,  4.92624297e-12,  3.19535105e-01, -2.16375804e-31],
        [ 6.15817352e-02, -4.92622929e-12, -2.05389745e-01,  4.92624297e-12,  1.42514481e+00,  4.92624493e-12, -4.89392646e-13],
        [ 3.01152918e-17, -2.23300746e-01, -3.48335303e-12,  3.19535105e-01,  4.92624493e-12,  1.07711265e+00, -1.11022891e-17],
        [-1.00000530e-01, -2.22045782e-17, -7.07110529e-02, -2.16375804e-31, -4.89392646e-13, -1.11022891e-17,  8.14286244e-01]]

numpy_array = np.array(data)
# print(numpy_array)

# %%
gazebo_data = np.array([[ 0.461159,   -0.0222727,     0.398968,   0.00144808,    0.0227893,   0.00186587,  -0.00726775],
                        [-0.0222727,       1.4448,    -0.019317,    -0.598865,    -0.012731,   -0.0452801,  0.000355564],
                        [ 0.398968,    -0.019317,     0.878795,   -0.0142492,    0.0104263,  0.000877132,  -0.00655689],
                        [ 0.00144808,    -0.598865,   -0.0142492,      0.78871,    0.0233624,    0.0931766,  -0.00127708],
                        [ 0.0227893,    -0.012731,    0.0104263,    0.0233624,    0.0278441,  0.000820188, -0.000788361],
                        [ 0.00186587,   -0.0452801,  0.000877132,    0.0931766,  0.000820188,    0.0325637,  -0.00157334],
                        [-0.00726775,  0.000355564,  -0.00655689,  -0.00127708, -0.000788361,  -0.00157334,   0.00490965]])

# %%
gazebo_jacobian = np.array([[1.70613e-05,     0.257286,  0.000302032,     0.024515,  9.29591e-05,     0.107008,            0],
                        [0.306916, -0.000410122,     0.398955,  0.000320965,     0.107006, -8.09528e-05,  1.05744e-17],
                        [0,    -0.306916, -0.000333836,     0.471992, -1.46028e-05,    0.0879905, -1.44219e-21],
                        [0,   0.00159403,    -0.707023, -0.000868716,            1, -0.000868727,  -8.8791e-05],
                        [0,     0.999999,   0.00112702,    -0.999999, -0.000868729,           -1, -0.000136389],
                        [1,  2.22045e-16,      0.70719,  0.000725142, -1.80035e-05,  0.000136467,           -1]])

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_matrix(matrix):
    plt.imshow(matrix, cmap='viridis', interpolation='nearest')
    plt.colorbar()
    plt.show()

# Replace this with your matrix data
matrix_data = new_robo - gazebo_data

plot_matrix(matrix_data)

# %%
import numpy as np
import matplotlib.pyplot as plt


class reward_multiplier:
    def __init__ (self,c_weight, f_w_weight,window):
        self.f_w_weight= f_w_weight         #force_in_window_weight
        self.c_weight = c_weight            #contact_fractional_weight
        self.f_t =4                        #force_target
        self.f_l=self.f_t-1                     #force_lower_limit    
        self.f_h=self.f_t+1                       #force_higher_limit
        self.f_cap=30                       #foce_upper_cap
        self.f_contact=0.3                  #min_contact_force
        self.window=window                  #whether to use force window
        self.f_r=False                       #force_reward
    
    def calc_multiplier(self):
        if self.window==True:
            f_limit_weight = 1 - self.f_w_weight - self.c_weight
            # print(c_weight, f_w_weight, f_limit_weight)
            min_reward = -1
            
            #calculations done for f_cap=30
            x = min_reward/(self.c_weight - self.f_w_weight- f_limit_weight)
            self.r_c = self.c_weight*x
            self.max_rc = self.c_weight*self.f_t
            r_w = self.f_w_weight*x
            r_l = f_limit_weight*x
            print(f"r_c:{self.r_c}, r_w:{r_w}, r_l:{r_l}")

            self.alpha_w = r_w/np.square(self.f_cap-self.f_t)
            self.alpha_h = r_l/(self.f_cap - self.f_h)**2
            self.alpha_l = self.alpha_h
            print(f"alpha_w:{self.alpha_w}, alpha_l:{self.alpha_l}, alpha_h: {self.alpha_h}")
            return self.r_c, self.alpha_l, self.alpha_w, self.alpha_h
        else:
            c_r=15                                                      #contact_reward
            tf_m = 1/self.c_weight                                      #target_force_mult, heuristically selected
            horizon=2000
            if self.f_r==True:
                self.norm_factor = horizon/(horizon*(c_r + tf_m))
            else:
                self.norm_factor = 1/c_r
            print(f"norm_factor:{self.norm_factor}")
            min_reward = -1
            f_m = ((-1/self.norm_factor)*(min_reward) +c_r)/((self.f_cap-self.f_t)**2)  #minimum reward = max penalty with no force rewards
            print(f"fm:{f_m}")
            return f_m, c_r, tf_m, self.norm_factor


class quadratic(reward_multiplier):
    def __init__ (self,c_weight, reward_scale, f_w_weight, window, force_reward):
        self.force_reward=True
        self.reward=0
        self.window_penalty=0
        self.l_penalty = 0
        self.h_penalty=0
        self.reward_scale=reward_scale
        self.force_reward = force_reward
        super().__init__(c_weight, f_w_weight,window)
        
            
    def calc_reward(self,x):
        if self.window==True:
            self.r_c, self.alpha_l, self.alpha_w, self.alpha_h = self.calc_multiplier()
            self.reward_scale=1/self.r_c
            window_penalty = self.alpha_w*np.square(x-self.f_t)
            self.reward -= self.alpha_w*np.square(x-self.f_t)
            print(f"reward_window:{self.reward}")
            if x>self.f_h:
                self.h_penalty = self.alpha_h*(x-self.f_h)**2
                self.reward-=self.h_penalty
                print(f"reward_exc:{-self.alpha_h*np.square(x-self.f_h)}")
            if x<self.f_l:
                self.l_penalty = self.alpha_l*(x-self.f_l)**2
                self.reward-=self.l_penalty
                print(f"reward_exc:{-self.alpha_l*np.square(x-self.f_l)}")
            if x<1. and x>0.3:
                self.l_penalty=self.alpha_l*np.square(x-1)
                self.reward-=self.l_penalty
            if x>=0.3:
                self.reward+=self.r_c
                # self.reward*=self.reward_scale
                print(f"r_c:{self.r_c}")
            if x>self.f_cap or self.reward*self.reward_scale<-1:
                self.reward = -1/self.reward_scale
            print(f"total_reward:{self.reward}")
            return window_penalty, self.l_penalty, self.h_penalty, self.r_c, self.reward*self.reward_scale
            # return self.reward
        else:
            self.alpha_h, self.r_c, self.alpha_w, self.norm_factor =self.calc_multiplier()
            if x>0.3:
                self.reward+=self.r_c
            self.alpha_l=self.alpha_h
            print(f"alpha_h:{self.alpha_h}")
            if x>0.3 and x!=self.f_t:
                force_penalty = self.alpha_h*(x-self.f_t)**2
                self.reward-=force_penalty
                # print(f"force_penalty:{force_penalty},reward:{reward}")
            if self.force_reward==True:
                print(f"alpha_w:{self.alpha_w}")
                if x>=self.f_l and x<self.f_h:
                    # print(f"alpha_w:{alpha_w}")
                    self.reward+=self.alpha_w
            # print(f"norm_factor:{norm_factor}")
            self.reward = self.norm_factor*self.reward*self.reward_scale
            if x >self.f_cap:
                self.reward=-1
            return self.reward

# class Rewards:
#     def r4(self, c,reward_scale, f, window=True, force_reward=True):
#         quadratic(c,reward_scale,f,window=window,force_reward=force_reward)

#     def r3 (self, c, reward_scale, f, window=False, force_reward=True):
#         quadratic(c,reward_scale,f,window=window,force_reward=force_reward)

#     def r2 (self, c, reward_scale, f, window=False, force_reward=False):
#         quadratic(c,reward_scale,f,window=window,force_reward=force_reward)
        

class plot_reward:
    def __init__ (self):

        self.x_values = np.arange(0.31,40,0.1)
        self.reward_scale=1
        self.c_weights= [0.5]
        self.f_w_weights = [0.3]
    
    def plot(self):
        # Plot the initial quadratic polynomial
        fig, ax = plt.subplots()
        for c in self.c_weights:
            for f in self.f_w_weights:
                w_p=[]
                h_p=[]
                r=[]
                R=[]
                for x in self.x_values:
                    # print(x)
                    # window_penalty, l_penalty, h_penalty, r_c, reward = quadratic(c,1,f,True,True).calc_reward(x)
                    # w_p.append(np.clip(window_penalty*-1 + reward,-1,2))
                    # h_p.append(h_penalty*-1)
                    # r.append(reward)
                    _r = quadratic(c,1,f,False,False).calc_reward(x)
                    R.append(_r)
                    # R.append(reward_2(x, 0.3, reward_scale=reward_scale, window=False))
                # ax.plot(self.x_values, w_p, label=f"wp+r_c: c_w:{c},f_w:{f}")
                # ax.plot(self.x_values,r, label=f"reward: c_w:{c},f_w:{f}")
                ax.plot(self.x_values,R, label=f"reward: c_w:{c}")
                ax.legend()
            ax.set_title('Quadratic Plot')
        plt.show()
P = plot_reward()
P.plot()
# Out:
# norm_factor:0.06666666666666667
# fm:0.04437869822485207
# alpha_h:0.04437869822485207
# norm_factor:0.06666666666666667
# fm:0.04437869822485207
# alpha_h:0.04437869822485207
# norm_factor:0.06666666666666667
# fm:0.04437869822485207
# alpha_h:0.04437869822485207
# norm_factor:0.06666666666666667
# fm:0.04437869822485207
# alpha_h:0.04437869822485207
# norm_factor:0.06666666666666667
# fm:0.04437869822485207
# alpha_h:0.04437869822485207
# norm_factor:0.06666666666666667
# fm:0.04437869822485207
# alpha_h:0.04437869822485207
# norm_factor:0.06666666666666667
# fm:0.04437869822485207
# alpha_h:0.04437869822485207
# norm_factor:0.06666666666666667
# fm:0.04437869822485207
# alpha_h:0.04437869822485207
# norm_factor:0.06666666666666667
# fm:0.04437869822485207
# alpha_h:0.04437869822485207
# norm_factor:0.06666666666666667
# fm:0.04437869822485207
# alpha_h:0.04437869822485207
# norm_factor:0.06666666666666667
# fm:0.04437869822485207
# alpha_h:0.04437869822485207
# ...

# %%
# for x in np.array(np.arange(0.31,4,0.1)):
#     print(x)
# Out:
# 0.31
# r_c:0.997005988023952, r_w:0.5988023952095808, r_l:1.3982035928143712
# alpha_w:0.0010395874916833, alpha_l:0.0028888503983768, alpha_h: 0.0028888503983768
# reward_window:-0.03365778858948769
# reward_exc:-0.039334875909338346
# r_c:0.997005988023952
# total_reward:0.924013323525126
# norm_factor:0.06666666666666667
# fm:0.052083333333333336
# alpha_h:0.052083333333333336
# 0.41000000000000003
# r_c:0.997005988023952, r_w:0.5988023952095808, r_l:1.3982035928143712
# alpha_w:0.0010395874916833, alpha_l:0.0028888503983768, alpha_h: 0.0028888503983768
# reward_window:-0.03248513389886892
# reward_exc:-0.037231792819320035
# r_c:0.997005988023952
# total_reward:0.927289061305763
# norm_factor:0.06666666666666667
# fm:0.052083333333333336
# alpha_h:0.052083333333333336
# 0.51
# r_c:0.997005988023952, r_w:0.5988023952095808, r_l:1.3982035928143712
# alpha_w:0.0010395874916833, alpha_l:0.0028888503983768, alpha_h: 0.0028888503983768
# reward_window:-0.03133327095808383
# ...
